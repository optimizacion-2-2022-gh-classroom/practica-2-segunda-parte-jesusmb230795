# %%
cd ..
# Out:
# /Users/jesusenriquemirandablanco/Documents/maestria/segundo/optimizacion/practica-2-segunda-parte-jesusmb230795

# %%
import pandas as pd
import numpy as np 
from datetime import date
import random
import networkx as nx
import time

# %%
from src.opt2.preprocessing import data_to_graph

# %%
ls ../data
# Out:
# ls: ../data: No such file or directory

# %%
start_time_c = time.time()
graph = data_to_graph(date='2022-05-03', path_to_file='./data/historical_data.csv')
graph.get_graph()
end_time = time.time()

secs_c = end_time-start_time_c
print("Arbitrage Identification Cycle in Crypto Trading tomó: ",secs_c,"segundos")
# Out:
# Arbitrage Identification Cycle in Crypto Trading tomó:  1.2224090099334717 segundos

# %%
graph.exchange_rate_matrix
# Out:
#                0             1             2             3             4   \
# 0        1.000000  6.359335e+01  7.326550e+00  1.818198e+01  5.589401e+01
# 1        0.016521  1.000000e+00  1.176800e-01  2.920413e-01  8.977767e-01
# 2        0.144447  8.930737e+00  1.000000e+00  2.553388e+00  7.849480e+00
# 3        0.057154  3.533646e+00  4.071091e-01  1.000000e+00  3.105822e+00
# 4        0.019150  1.184017e+00  1.364098e-01  3.385223e-01  1.000000e+00
# ..            ...           ...           ...           ...           ...
# 95       2.682632  1.658590e+02  1.910851e+01  4.742075e+01  1.457782e+02
# 96  168189.944673  1.039867e+07  1.198024e+06  2.973085e+06  9.139689e+06
# 97       0.016372  1.012242e+00  1.166198e-01  2.894103e-01  8.896886e-01
# 98       0.478589  2.958968e+01  3.409009e+00  8.459988e+00  2.600722e+01
# 99       1.723024  1.065293e+02  1.227317e+01  3.045780e+01  9.363164e+01
#
#               5             6             7            8            9   ...  \
# ...

# %%
data.graph
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-20d03cb4e021> in <module>
# ----> 1 data.graph
#
# AttributeError: 'data_to_graph' object has no attribute 'graph'
